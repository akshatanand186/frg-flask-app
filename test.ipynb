# %%
from model import ClusteringModel

# %%
model = ClusteringModel()
input_dict = {
    'gender': 'Men',
    'subCategory': 'Topwear',
    'articleType': 'Shirts',
    'baseColour': 'Blue',
    'usage': 'Casual'
}

id_list = model.predict(input_dict)
# Out:
# c:\Users\kayde\OneDrive\Desktop\frg-flask-app\.venv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %%
from database import MongoInstance
import config
from crud import get_multiple_fashion, get_fashion

db = MongoInstance(uri = config.mongo_uri, db_name=config.db_name).db
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
f_list = get_multiple_fashion(db, id_list)
f_sample = get_fashion(db, id_list[0])

# %%
for doc in f_list:
    print(doc['productDisplayName'])
# Out:
# Lee Men checks Blue Shirt
# Lee Men Light Blue Shirt
# Lee Men Reversible Blue Shirt
# Lee Men Check Mason Blue Shirt
# Lee Men Checks Red Shirt
# Basics Men Blue Slim Fit Checked Shirt
# Probase Men Blue Slim Fit Solid Casual Shirt
# Probase Men Check Blue Shirt
# Probase Men Check Orange Shirt
# Probase Men Blue & White Shirt
# Probase Men Check Brown Shirt
# Disney Kids Girl's Blue Check Kidswear Shirt
# Levis Kids Boy's Calcio Grey Blue Kidswear
# Locomotive Men Blue Checked Shirt
# Locomotive Men Blue Checked Shirt
# Locomotive Men Blue Red Checked Shirt
# Locomotive Men Blue Checked Shirt
# Highlander Men Blue Check Shirt
# Highlander Men Solid Poplin Blue Shirt
# Locomotive Men Blue White Brown Checked Shirt
# Locomotive Men Blue Grey White Checked Shirt
# Locomotive Men Blue Black Grey Checked Shirt
# Highlander Men Blue Black Checked Shirt
# Locomotive Men Blue Checked Shirt
# Highlander Men Blue Brown Checked Shirt
# Highlander Men Blue Red Plaid Checked Shirt
# ...

# %%
from openAI import OpenAI

davinci = OpenAI()

# %%
davinci.request('Black shirts for men')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 davinci.request('Black shirts for men')
#
# File c:\Users\kayde\OneDrive\Desktop\frg-flask-app\openAI.py:134, in OpenAI.request(self, query)
#     131 max_tokens = 4000 - num_prompt_tokens # calculate the max available tokens for the response
#     133 # call the OpenAI API
# --> 134 response = openai.Completion.create(
#     135     model='text-davinci-003', # the best GPT-3 model
#     136     prompt=full_prompt,
#     137     temperature=0,
#     138     max_tokens=max_tokens,
#     139     top_p=0.1,
#     140     stop=['```'],
#     141     echo=True # returns the whole prompt including the completion
#     142 )
#     144 result_raw = response.choices[0].text
#     145 json_str = result_raw.split('```json')[1].strip() # since we used echo=True, we can split on the json marker
#
# ...

# %%
from utils import QueryToJson

query_to_json = QueryToJson()

query_to_json.get_json('Blue shirt casual')
# Out:
# {'error': 'Model requires a Pro subscription'}
